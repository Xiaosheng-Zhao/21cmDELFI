# %% [markdown]
# # Training of the models
# In this notebook, you can choose your own data and model parameters, train the model, and make a plot for the single PDFs or the joint contours with an individual trained model or the stacked one.

# %%
import os
#os.environ["CUDA_VISIBLE_DEVICES"] = "4"
import numpy as np
import matplotlib.pyplot as plt
import pydelfi.priors as priors
import pydelfi.ndes as ndes
import pydelfi.delfi as delfi
import tensorflow as tf
import pickle
from getdist import plots, MCSamples
import getdist

tf.logging.set_verbosity(tf.logging.ERROR)
config = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1, allow_soft_placement=True, device_count = {'CPU': 1})
session = tf.Session(config=config)

# %matplotlib inline
# Out:
# WARNING:tensorflow:From /home/zxs/miniconda3/envs/21cmfast/lib/python3.6/site-packages/pydelfi-0.1-py3.6.egg/pydelfi/train.py:9: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.

# %% [markdown]
# ## prepare the data

# %%
#define the parameter prior 
lower = np.array([4,1])
upper = np.array([6,2.398])
prior = priors.Uniform(lower, upper)

#testing data
theta_fiducials = np.load('data/hera_para_mock.npy')
compressed_datas = np.load('data/hera_ps_mock.npy')

#training data
sim_params = np.load('data/hera_para.npy')
sim_compressed_data=np.load('data/hera_ps.npy')

#dimension of the data summary
nd=compressed_datas.shape[1]

#0 for the faint model; 1 for the bright model
theta_fiducial = theta_fiducials[1]
compressed_data = compressed_datas[1]

#directory of the results
diri = "data/diagnostics/trained_hera/"

# %%
sim_compressed_data.shape
# Out:
# (9000, 80)

# %% [markdown]
# ## Choose the model

# %%
NDEs = [ndes.ConditionalMaskedAutoregressiveFlow(n_parameters=2, n_data=nd, n_hiddens=[50,50], n_mades=5, act_fun=tf.tanh, index=0),
            ndes.ConditionalMaskedAutoregressiveFlow(n_parameters=2, n_data=nd, n_hiddens=[50,50], n_mades=5, act_fun=tf.tanh, index=1),
            ndes.ConditionalMaskedAutoregressiveFlow(n_parameters=2, n_data=nd, n_hiddens=[50,50], n_mades=5, act_fun=tf.tanh, index=2),
            ndes.ConditionalMaskedAutoregressiveFlow(n_parameters=2, n_data=nd, n_hiddens=[50,50], n_mades=5, act_fun=tf.tanh, index=3)]

# %% [markdown]
# ## initialization

# %%
DelfiEnsemble = delfi.Delfi(compressed_data, prior, NDEs, 
                            Finv = None, 
                            n_procs = 1,
                            theta_fiducial = theta_fiducial, 
                            param_limits = [lower, upper],
                            param_names = ['\mathrm{log_{10}\,T_{vir}}', '\mathrm{log_{10}\,\zeta}'], 
                            results_dir = diri,
                            progress_bar = False,
                            input_normalization=None)

# %% [markdown]
# ## data loading and training

# %%
# %%time
DelfiEnsemble.load_simulations(sim_compressed_data, sim_params)
DelfiEnsemble.train_ndes()
# Out:
# CPU times: user 2min 8s, sys: 2.1 s, total: 2min 10s
# Wall time: 2min 11s

# %% [markdown]
# ## sample and save the posteriors

# %%
# %%time
posterior_samples = DelfiEnsemble.emcee_sample(burn_in_chain=600, main_chain=1000)
with open('data/posterior_samples/po_mock.pkl', 'wb') as f:
    pickle.dump(posterior_samples,f)
# Out:
# /home/zxs/miniconda3/envs/21cmfast/lib/python3.6/site-packages/pydelfi-0.1-py3.6.egg/pydelfi/delfi.py:230: RuntimeWarning: divide by zero encountered in log
# CPU times: user 4min 6s, sys: 3.92 s, total: 4min 10s
# Wall time: 4min 5s

# %% [markdown]
# ## plot the results

# %%
# %matplotlib inline
from getdist import plots, MCSamples
import getdist

param_names = ['$\mathrm{log_{10}(T_{vir})[K]}$', '$\mathrm{log_{10}\,\zeta}$']

def plots_all(d_all,colorl,colorx):
    sample1 = MCSamples(samples=[d_all[:,0]],names = [param_names[0]], labels = param_names[0])
    sample2 = MCSamples(samples=[d_all[:,1]],names = [param_names[1]], labels = param_names[1])
    g.add_1d(sample1,param_names[0], ax=ax[0,0], color=colorl)
    g.add_1d(sample2,param_names[1], ax=ax[1,1], color=colorl)
    sample12 = MCSamples(samples=d_all,names = param_names, labels = param_names)
    con1 = g.add_2d_contours(sample12, param_names[0], param_names[1], ax=ax[1,0], color=colorl, filled = False,contour_levels=[0.32,0.05])

for num in range(1):
    fig, ax = plt.subplots(figsize=(9,9),nrows=2, ncols=2, gridspec_kw={'hspace': 0, 'wspace': 0})
    ax[0,0].set_yticks([])
    ax[0,0].set_xlim(4,6)
    ax[0,0].set_ylim(0,1.1)
    ax[0,0].axvline(theta_fiducial[0], linestyle='--', c = 'k', lw = .8)
    ax[0,0].set_xticks([4.2, 4.7, 5.2, 5.7])
    ax[0,0].tick_params(axis = 'x', top = False, direction = "in", length = 6)
    
    ax[0,1].set(frame_on=False)
    ax[0,1].set_yticks([])
    ax[0,1].set_xticks([])
    ax[1,0].set_xlim(4,6)
    ax[1,0].set_ylim(1,2.4)
    ax[1,0].set_xticks([4.2, 4.7, 5.2, 5.7])
    ax[1,0].set_yticks([1.2, 1.5, 1.8, 2.1])
    
    ax[1,0].tick_params(axis = 'both', top = True, right = True, direction = "in", length = 6)
    ax[1,0].axvline(theta_fiducial[0], linestyle = '--', c = 'k', lw = .8)
    ax[1,0].axhline(theta_fiducial[1], linestyle = '--', c = 'k', lw = .8)
    ax[1,0].set_xlabel("$\mathrm{log_{10}(T_{vir})[K]}$",fontsize=15)
    ax[1,0].set_ylabel("$\mathrm{log_{10}\,\zeta}$",fontsize=15)
    ax[1,1].set_yticks([])
    ax[1,1].set_xlim(1,2.4)
    ax[1,1].set_ylim(0,1.1)
    ax[1,1].set_xticks([1.2, 1.5, 1.8, 2.1])
    ax[1,1].tick_params(axis = 'x', top = False, direction = "in", length = 6)
    ax[1,1].axvline(theta_fiducial[1], linestyle = '--', c = 'k', lw = .8)
    ax[1,1].set_xlabel("$\mathrm{log_{10}\,\zeta}$",fontsize=15)
    
    g = plots.getSinglePlotter(width_inch=4)
    f = open("data/posterior_samples/po_mock.pkl", 'rb')
    d = pickle.load(f)
    sample=np.unique(d[0], axis=0, return_counts=False)
    plots_all(sample,'red','red')
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ## sample the posteriors with individual NDE components

# %%
p_single_likelihood = DelfiEnsemble.emcee_sample_single_train(burn_in_chain=600, main_chain=1000,path='data/posterior_samples/')

# %%
# !du -sh data/posterior_samples
# Out:
# 22M	data/posterior_samples

# %% [markdown]
# ## plot the results

# %%
param_names = ['$\mathrm{log_{10}(T_{vir})[K]}$', '$\mathrm{log_{10}\,\zeta}$']
restore_filename='data/diagnostics/trained_hera/restore.pkl'
stacking_weights,  posterior_samples,  proposal_samples,  training_loss,  validation_loss,  stacked_sequential_training_loss,  stacked_sequential_validation_loss,  sequential_nsims,  ps,  xs,  x_mean,  x_std,  p_mean,  p_std = pickle.load(open( restore_filename, 'rb'))

# %%
def plots_all(d_all,colorl,colorx):
    sample1 = MCSamples(samples=[d_all[:,0]],names = [param_names[0]], labels = param_names[0])
    sample2 = MCSamples(samples=[d_all[:,1]],names = [param_names[1]], labels = param_names[1])
    g.add_1d(sample1,param_names[0], ax=ax[0,0], color=colorl)
    g.add_1d(sample2,param_names[1], ax=ax[1,1], color=colorl)
    sample12 = MCSamples(samples=d_all,names = param_names, labels = param_names)
    con1 = g.add_2d_contours(sample12, param_names[0], param_names[1], ax=ax[1,0], color=colorl, filled = False,contour_levels=[0.32,0.05])


Nde=['MAF0','MAF1','MAF2','MAF3']

for num in range(4):
    fig, ax = plt.subplots(figsize=(9,9),nrows=2, ncols=2, gridspec_kw={'hspace': 0, 'wspace': 0})
    ax[0,0].set_yticks([])
    ax[0,0].set_xlim(4,6)
    ax[0,0].set_ylim(0,1.1)
    ax[0,0].axvline(theta_fiducial[0], linestyle='--', c = 'k', lw = .8)
    ax[0,0].set_xticks([4.2, 4.7, 5.2, 5.7])
    ax[0,0].tick_params(axis = 'x', top = False, direction = "in", length = 6)

    ax[0,1].set(frame_on=False)
    ax[0,1].set_yticks([])
    ax[0,1].set_xticks([])


    ax[1,0].set_xlim(4,6)
    ax[1,0].set_ylim(1,2.4)
    ax[1,0].set_xticks([4.2, 4.7, 5.2, 5.7])
    ax[1,0].set_yticks([1.2, 1.5, 1.8, 2.1])
    
    ax[1,0].tick_params(axis = 'both', top = True, right = True, direction = "in", length = 6)
    ax[1,0].axvline(theta_fiducial[0], linestyle = '--', c = 'k', lw = .8)
    ax[1,0].axhline(theta_fiducial[1], linestyle = '--', c = 'k', lw = .8)
    ax[1,0].set_xlabel("$\mathrm{log_{10}(T_{vir})[K]}$",fontsize=15)
    ax[1,0].set_ylabel("$\mathrm{log_{10}\,\zeta}$",fontsize=15)

    ax[1,1].set_yticks([])
    ax[1,1].set_xlim(1,2.4)
    ax[1,1].set_ylim(0,1.1)
    ax[1,1].set_xticks([1.2, 1.5, 1.8, 2.1])
    ax[1,1].tick_params(axis = 'x', top = False, direction = "in", length = 6)
    ax[1,1].axvline(theta_fiducial[1], linestyle = '--', c = 'k', lw = .8)
    ax[1,1].set_xlabel("$\mathrm{log_{10}\,\zeta}$",fontsize=15)
    
    #fig1 = plt.gcf()
    g = plots.getSinglePlotter(width_inch=4)
    
    f = open("data/posterior_samples/po_mock.pkl", 'rb')
    d = pickle.load(f)
    sample=np.unique(d[0], axis=0, return_counts=False)
    plots_all(sample,'red','red')
    
    f = open("data/posterior_samples/po_mock_nde{:d}.pkl".format(num), 'rb') 
    d = pickle.load(f)
    sample=np.unique(d[0], axis=0, return_counts=False)
    plots_all(sample,'slateblue','darkblue')
    
    ax[0,1].text(0.4,0.7,'{:s}: weight={:.3f}'.format(Nde[num],stacking_weights[num]),fontsize=14)
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
